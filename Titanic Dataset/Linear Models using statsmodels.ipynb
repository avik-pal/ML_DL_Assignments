# %%
import pandas as pd
import statsmodels.api as sta
import statsmodels.formula.api as stf
from sklearn import linear_model as lm
import numpy as nm
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
train = pd.read_csv('train_final.csv')
test = pd.read_csv('test_final.csv')
test.head()
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
model1 = stf.logit(formula='Survived ~ Pclass + Sex + Age + SibSp + Parch + Fare + Embarked',data=train)
results1 = model1.fit()
results1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.440985
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  889
# Model:                          Logit   Df Residuals:                      880
# Method:                           MLE   Df Model:                            8
# Date:                Thu, 28 Sep 2017   Pseudo R-squ.:                  0.3371
# Time:                        13:49:54   Log-Likelihood:                -392.04
# converged:                       True   LL-Null:                       -591.41
#                                         LLR p-value:                 3.473e-81
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
nm.exp(results1.params)
# Out:
# Intercept        198.539201
# Sex[T.male]        0.065975
# Embarked[T.Q]      0.971442
# Embarked[T.S]      0.656942
# Pclass             0.332816
# Age                0.960810
# SibSp              0.721804
# Parch              0.910924
# Fare               1.001916
# dtype: float64

# %%
test['Survival_Pred'] = results2.predict(test)>0.67;

# %%
test.head()
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked  Survival_Pred
# 0   330911   7.8292        Q          False
# 1   363272   7.0000        S          False
# 2   240276   9.6875        Q          False
# 3   315154   8.6625        S          False
# 4  3101298  12.2875        S           True

# %%
train['Survival_Pred'] = (results1.predict(train)>0.7);

# %%
train.head(2)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked  Survival_Pred
# 0      0  A/5 21171   7.2500        S          False
# 1      0   PC 17599  71.2833        C           True

# %%
train[['Survived','Survival_Pred']].head(10)
# Out:
#    Survived  Survival_Pred
# 0         0          False
# 1         1           True
# 2         1           True
# 3         1           True
# 4         0          False
# 5         0          False
# 6         0          False
# 7         0          False
# 8         1           True
# 9         1           True

# %%
train.groupby('Survival_Pred')

# %%
t = (train.loc[train.Survived == 0, 'Survival_Pred'])
countF1 = 0
countT1 = 0
for i in t:
    if(i):
        countT1 = countT1 + 1
    else:
        countF1 = countF1 + 1
t = (train.loc[train.Survived == 1, 'Survival_Pred'])
countF2 = 0
countT2 = 0
for i in t:
    if(i):
        countT2 = countT + 1
    else:
        countF2 = countF + 1
(countF1+countT2)/(countF1+countT1+countF2+countT2)
# Out:
# 0.8641975308641975

# %%
(239+474)/(239+474+101+75)
# Out:
# 0.8020247469066367

# %%
model2 = stf.logit(formula='Survived ~ Pclass + Sex + Age + SibSp + Parch + Embarked',data=train)
results2 = model2.fit()
print(results2.summary())
train['Survival_Pred2'] = (results2.predict(train)>0.67);
t = (train.loc[train.Survived == 0, 'Survival_Pred2'])
countF1 = 0
countT1 = 0
for i in t:
    if(i):
        countT1 = countT1 + 1
    else:
        countF1 = countF1 + 1
t = (train.loc[train.Survived == 1, 'Survival_Pred2'])
countF2 = 0
countT2 = 0
for i in t:
    if(i):
        countT2 = countT2 + 1
    else:
        countF2 = countF2 + 1
print((countF1+countT2)/(countF1+countT1+countF2+countT2))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.441373
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  889
# Model:                          Logit   Df Residuals:                      881
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 28 Sep 2017   Pseudo R-squ.:                  0.3365
# Time:                        17:53:55   Log-Likelihood:                -392.38
# converged:                       True   LL-Null:                       -591.41
#                                         LLR p-value:                 6.228e-82
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         5.5018      0.505     10.887      0.000       4.511       6.492
# ...

# %%
model3 = stf.logit(formula='Survived ~ Fare + Sex + Age + SibSp + Parch + Embarked',data=train)
results3 = model3.fit()
print(results3.summary())
train['Survival_Pred3'] = (results3.predict(train)>0.5);
t = (train.loc[train.Survived == 0, 'Survival_Pred3'])
countF1 = 0
countT1 = 0
for i in t:
    if(i):
        countT1 = countT1 + 1
    else:
        countF1 = countF1 + 1
t = (train.loc[train.Survived == 1, 'Survival_Pred3'])
countF2 = 0
countT2 = 0
for i in t:
    if(i):
        countT2 = countT2 + 1
    else:
        countF2 = countF2 + 1
print((countF1+countT2)/(countF1+countT1+countF2+countT2))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.474396
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  889
# Model:                          Logit   Df Residuals:                      881
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 28 Sep 2017   Pseudo R-squ.:                  0.2869
# Time:                        17:41:09   Log-Likelihood:                -421.74
# converged:                       True   LL-Null:                       -591.41
#                                         LLR p-value:                 2.353e-69
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.0257      0.338      5.988      0.000       1.363       2.689
# ...

# %%
model4 = stf.logit(formula='Survived ~ Fare + Sex + Age + SibSp + Parch',data=train)
results4 = model4.fit()
print(results4.summary())
train['Survival_Pred4'] = (results4.predict(train)>0.5);
t = (train.loc[train.Survived == 0, 'Survival_Pred4'])
countF1 = 0
countT1 = 0
for i in t:
    if(i):
        countT1 = countT1 + 1
    else:
        countF1 = countF1 + 1
t = (train.loc[train.Survived == 1, 'Survival_Pred4'])
countF2 = 0
countT2 = 0
for i in t:
    if(i):
        countT2 = countT2 + 1
    else:
        countF2 = countF2 + 1
print((countF1+countT2)/(countF1+countT1+countF2+countT2))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.477549
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  889
# Model:                          Logit   Df Residuals:                      883
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 28 Sep 2017   Pseudo R-squ.:                  0.2822
# Time:                        17:42:15   Log-Likelihood:                -424.54
# converged:                       True   LL-Null:                       -591.41
#                                         LLR p-value:                 5.549e-70
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       1.5673      0.272      5.764      0.000       1.034       2.100
# ...

# %%
model5 = stf.logit(formula='Survived ~ Pclass + Sex + Age + SibSp + Parch',data=train)
results5 = model5.fit()
print(results5.summary())
train['Survival_Pred5'] = (results5.predict(train)>0.5);
t = (train.loc[train.Survived == 0, 'Survival_Pred5'])
countF1 = 0
countT1 = 0
for i in t:
    if(i):
        countT1 = countT1 + 1
    else:
        countF1 = countF1 + 1
t = (train.loc[train.Survived == 1, 'Survival_Pred5'])
countF2 = 0
countT2 = 0
for i in t:
    if(i):
        countT2 = countT2 + 1
    else:
        countF2 = countF2 + 1
print((countF1+countT2)/(countF1+countT1+countF2+countT2))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.444175
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  889
# Model:                          Logit   Df Residuals:                      883
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 28 Sep 2017   Pseudo R-squ.:                  0.3323
# Time:                        17:43:07   Log-Likelihood:                -394.87
# converged:                       True   LL-Null:                       -591.41
#                                         LLR p-value:                 9.217e-83
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       5.2362      0.484     10.824      0.000       4.288       6.184
# ...

# %%
train
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# 5             5            6         0       3
# 6             6            7         0       1
# 7             7            8         0       3
# 8             8            9         1       3
# 9             9           10         1       2
# 10           10           11         1       3
# 11           11           12         1       1
# 12           12           13         0       3
# 13           13           14         0       3
# 14           14           15         0       3
# 15           15           16         1       2
# 16           16           17         0       3
# 17           17           18         1       2
# 18           18           19         0       3
# ...

# %%
(train['Fare']).corr(train['Age'])
# Out:
# 0.087674492590164979

# %%
j = 0
for i in results2.predict(test):
    if i > 0.67:
        test['Survived'][j] = 1
    else:
        test['Survived'][j] = 0
    j=j+1
# Out:
# /home/avikpal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/avikpal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
test
# Out:
#      Unnamed: 0  PassengerId  Pclass  \
# 0             0          892       3
# 1             1          893       3
# 2             2          894       2
# 3             3          895       3
# 4             4          896       3
# 5             5          897       3
# 6             6          898       3
# 7             7          899       2
# 8             8          900       3
# 9             9          901       3
# 10           10          902       3
# 11           11          903       1
# 12           12          904       1
# 13           13          905       2
# 14           14          906       1
# 15           15          907       2
# 16           16          908       2
# 17           17          909       3
# 18           18          910       3
# 19           19          911       3
# 20           20          912       1
# 21           21          913       3
# 22           22          914       1
# 23           23          915       1
# ...

# %%
test[['PassengerId','Survived']].to_csv('LinearModelSolutions1.csv',index=False)

# %%
###Received accuracy of 73% on Kaggle
